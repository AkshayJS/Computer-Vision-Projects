# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshayJS/Computer-Vision-Projects/blob/main/Inception_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Inception/GoogleNet implementation with Keras

# %% [markdown]
# ### 1. Import libraries

# %%
import cv2 
import numpy as np 
import keras
import math
#from tensorflow.keras.layers.core import Layer
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPool2D, UpSampling2D, \
    Dropout, Dense, Input, concatenate,      \
    GlobalAveragePooling2D, AveragePooling2D,\
    Flatten
from tensorflow.keras.datasets import cifar10 
from tensorflow.keras import backend as K 
from keras.utils import np_utils 
from tensorflow.keras.optimizers import SGD 
from tensorflow.keras.callbacks import LearningRateScheduler

# %% [markdown]
# ### 2. Prepare the dataset

# %%
num_classes = 10

def load_cifar10_data(img_rows, img_cols):

    # Load cifar10 training and validation sets
    (X_train, Y_train), (X_valid, Y_valid) = cifar10.load_data()

    # Resize training images
    X_train = np.array([cv2.resize(img, (img_rows,img_cols)) for img in X_train[:,:,:,:]])
    X_valid = np.array([cv2.resize(img, (img_rows,img_cols)) for img in X_valid[:,:,:,:]])

    # Transform targets to keras compatible format
    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_valid = np_utils.to_categorical(Y_valid, num_classes)
    
    X_train = X_train.astype('float32')
    X_valid = X_valid.astype('float32')

    # preprocess data
    X_train = X_train / 255.0
    X_valid = X_valid / 255.0

    return X_train, Y_train, X_valid, Y_valid

# %%
X_train, y_train, X_test, y_test = load_cifar10_data(28, 28)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
def inception_module(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_5x5,
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %% [markdown]
# ### 4. Create the GoogLeNet architecture

# %%
kernel_init = keras.initializers.glorot_uniform()
bias_init = keras.initializers.Constant(value=0.2)

# %%
input_layer = Input(shape=(28, 28, 3))

x = UpSampling2D((2,2))(input_layer)
x = UpSampling2D((2,2))(x)
x = UpSampling2D((2,2))(x)
x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
# x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=192,
                     filters_3x3_reduce=96,
                     filters_3x3=208,
                     filters_5x5_reduce=16,
                     filters_5x5=48,
                     filters_pool_proj=64,
                     name='inception_4a')


classifier_1 = AveragePooling2D((5, 5), strides=3)(x)
classifier_1 = Conv2D(128, (1, 1), padding='same', activation='relu')(classifier_1)
classifier_1 = Flatten()(classifier_1)
classifier_1 = Dense(1024, activation='relu')(classifier_1)
classifier_1 = Dropout(0.7)(classifier_1)
classifier_1 = Dense(10, activation='softmax', name='auxilliary_output_1')(classifier_1)

x = inception_module(x,
                     filters_1x1=160,
                     filters_3x3_reduce=112,
                     filters_3x3=224,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4b')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=256,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4c')

x = inception_module(x,
                     filters_1x1=112,
                     filters_3x3_reduce=144,
                     filters_3x3=288,
                     filters_5x5_reduce=32,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4d')


classifier_2 = AveragePooling2D((5, 5), strides=3)(x)
classifier_2 = Conv2D(128, (1, 1), padding='same', activation='relu')(classifier_2)
classifier_2 = Flatten()(classifier_2)
classifier_2 = Dense(1024, activation='relu')(classifier_2)
classifier_2 = Dropout(0.7)(classifier_2)
classifier_2 = Dense(10, activation='softmax', name='auxilliary_output_2')(classifier_2)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_4e')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = AveragePooling2D(pool_size=(7,7), strides=1, padding='valid',name='avg_pool_5_3x3/1')(x)

x = Dropout(0.2)(x)
x = Flatten()(x)
x = Dense(1000, activation='relu', name='linear')(x)
x = Dense(10, activation='softmax', name='output')(x)

# %% [markdown]
# ### GoogleNet model without the classfiers 1 and 2

# %%
model = Model(input_layer, [x], name='googlenet')

# %%
model.summary()
# Out:
# Model: "googlenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 3)]  0
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 56, 56, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 112, 112, 3)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 224, 224, 3)  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 112, 112, 64) 9472        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 56, 56, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 56, 56, 192)  110784      max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 28, 28, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 128)  110720      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 32)   12832       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 32)   6176        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 28, 28, 256)  0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 32)   8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 256)  0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 192)  221376      conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 96)   76896       conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 64)   16448       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 28, 28, 480)  0           conv2d_6[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 14, 14, 480)  0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 96)   46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 16)   7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 192)  92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 208)  179920      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 48)   19248       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 64)   30784       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 14, 14, 512)  0           conv2d_12[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 112)  57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 24)   12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 160)  82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 224)  226016      conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 14, 14, 512)  0           conv2d_19[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 24)   12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 256)  295168      conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 14, 14, 512)  0           conv2d_25[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 144)  73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 32)   16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 112)  57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 288)  373536      conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 14, 14, 528)  0           conv2d_31[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 160)  84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 32)   16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 528)  0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 256)  135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 320)  461120      conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 128)  102528      conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  67712       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 14, 14, 832)  0           conv2d_38[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 7, 7, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 7, 7, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 320)    461120      conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 128)    102528      conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 7, 7, 832)    0           conv2d_44[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 384)    663936      conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 128)    153728      conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 7, 7, 1024)   0           conv2d_50[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (AveragePoolin (None, 1, 1, 1024)   0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1, 1, 1024)   0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# linear (Dense)                  (None, 1000)         1025000     flatten_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 10)           10010       linear[0][0]
# ==================================================================================================
# Total params: 7,004,402
# Trainable params: 7,004,402
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### GoogLeNet model after adding classifiers 1 and 2

# %%
model_with_classifiers = Model(input_layer, [x, classifier_1, classifier_2], name='googlenet_complete_architecture')
model_with_classifiers.summary()
# Out:
# Model: "googlenet_complete_architecture"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 3)]  0
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 56, 56, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 112, 112, 3)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 224, 224, 3)  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 112, 112, 64) 9472        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 56, 56, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 56, 56, 192)  110784      max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 28, 28, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 28, 28, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 128)  110720      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 32)   12832       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 32)   6176        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 28, 28, 256)  0           conv2d[0][0]
#                                                                  conv2d_2[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 32)   8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 256)  0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 192)  221376      conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 96)   76896       conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 64)   16448       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 28, 28, 480)  0           conv2d_6[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 14, 14, 480)  0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 96)   46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 16)   7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 14, 14, 192)  92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 208)  179920      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 48)   19248       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 64)   30784       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 14, 14, 512)  0           conv2d_12[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 112)  57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 24)   12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 160)  82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 224)  226016      conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 14, 14, 512)  0           conv2d_19[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 24)   12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 256)  295168      conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 14, 14, 512)  0           conv2d_25[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 144)  73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 32)   16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 112)  57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 288)  373536      conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 14, 14, 528)  0           conv2d_31[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 160)  84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 32)   16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 528)  0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 256)  135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 320)  461120      conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 128)  102528      conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  67712       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 14, 14, 832)  0           conv2d_38[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 7, 7, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 7, 7, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 320)    461120      conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 128)    102528      conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 7, 7, 832)    0           conv2d_44[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 384)    663936      conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 128)    153728      conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 7, 7, 1024)   0           conv2d_50[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 4, 4, 512)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 528)    0           inception_4d[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (AveragePoolin (None, 1, 1, 1024)   0           inception_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 128)    65664       average_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 4, 4, 128)    67712       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1, 1, 1024)   0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2048)         0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1024)         0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024)         2098176     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# linear (Dense)                  (None, 1000)         1025000     flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           dense[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 10)           10010       linear[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_1 (Dense)     (None, 10)           10250       dropout[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_2 (Dense)     (None, 10)           10250       dropout_1[0][0]
# ==================================================================================================
# Total params: 11,354,630
# Trainable params: 11,354,630
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### compile a network with three models

# %%
epochs = 25
initial_lrate = 0.01

def decay(epoch, steps=100):
    initial_lrate = 0.01
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

sgd = SGD(lr=initial_lrate, momentum=0.9, nesterov=False)

lr_sc = LearningRateScheduler(decay, verbose=1)

model_with_classifiers.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], 
              loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])

history = model_with_classifiers.fit(X_train, [y_train, y_train, y_train], validation_data=(X_test, [y_test, y_test, y_test]), 
                    epochs=epochs, batch_size=256, callbacks=[lr_sc])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/25
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.01.
# 196/196 [==============================] - 431s 2s/step - loss: 3.5441 - output_loss: 2.2197 - auxilliary_output_1_loss: 2.1992 - auxilliary_output_2_loss: 2.2153 - output_accuracy: 0.1519 - auxilliary_output_1_accuracy: 0.1670 - auxilliary_output_2_accuracy: 0.1571 - val_loss: 3.2104 - val_output_loss: 2.0279 - val_auxilliary_output_1_loss: 1.9683 - val_auxilliary_output_2_loss: 1.9733 - val_output_accuracy: 0.2441 - val_auxilliary_output_1_accuracy: 0.2800 - val_auxilliary_output_2_accuracy: 0.2732
# Epoch 2/25
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.01.
# 196/196 [==============================] - 352s 2s/step - loss: 3.0834 - output_loss: 1.9352 - auxilliary_output_1_loss: 1.9079 - auxilliary_output_2_loss: 1.9193 - output_accuracy: 0.2731 - auxilliary_output_1_accuracy: 0.2991 - auxilliary_output_2_accuracy: 0.2886 - val_loss: 2.8297 - val_output_loss: 1.8061 - val_auxilliary_output_1_loss: 1.6980 - val_auxilliary_output_2_loss: 1.7140 - val_output_accuracy: 0.3132 - val_auxilliary_output_1_accuracy: 0.3989 - val_auxilliary_output_2_accuracy: 0.3872
# Epoch 3/25
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.01.
# 196/196 [==============================] - 352s 2s/step - loss: 2.7578 - output_loss: 1.7280 - auxilliary_output_1_loss: 1.7165 - auxilliary_output_2_loss: 1.7163 - output_accuracy: 0.3539 - auxilliary_output_1_accuracy: 0.3739 - auxilliary_output_2_accuracy: 0.3672 - val_loss: 2.5390 - val_output_loss: 1.5936 - val_auxilliary_output_1_loss: 1.5716 - val_auxilliary_output_2_loss: 1.5798 - val_output_accuracy: 0.4127 - val_auxilliary_output_1_accuracy: 0.4316 - val_auxilliary_output_2_accuracy: 0.4187
# Epoch 4/25
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.01.
# 196/196 [==============================] - 353s 2s/step - loss: 2.4981 - output_loss: 1.5516 - auxilliary_output_1_loss: 1.5858 - auxilliary_output_2_loss: 1.5692 - output_accuracy: 0.4169 - auxilliary_output_1_accuracy: 0.4201 - auxilliary_output_2_accuracy: 0.4176 - val_loss: 2.3604 - val_output_loss: 1.4919 - val_auxilliary_output_1_loss: 1.4480 - val_auxilliary_output_2_loss: 1.4470 - val_output_accuracy: 0.4449 - val_auxilliary_output_1_accuracy: 0.4750 - val_auxilliary_output_2_accuracy: 0.4731
# Epoch 5/25
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.01.
# 196/196 [==============================] - 353s 2s/step - loss: 2.2904 - output_loss: 1.4153 - auxilliary_output_1_loss: 1.4712 - auxilliary_output_2_loss: 1.4458 - output_accuracy: 0.4747 - auxilliary_output_1_accuracy: 0.4620 - auxilliary_output_2_accuracy: 0.4676 - val_loss: 2.1064 - val_output_loss: 1.3175 - val_auxilliary_output_1_loss: 1.3306 - val_auxilliary_output_2_loss: 1.2989 - val_output_accuracy: 0.5097 - val_auxilliary_output_1_accuracy: 0.5131 - val_auxilliary_output_2_accuracy: 0.5280
# Epoch 6/25
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.01.
# 196/196 [==============================] - 353s 2s/step - loss: 2.1213 - output_loss: 1.3051 - auxilliary_output_1_loss: 1.3803 - auxilliary_output_2_loss: 1.3404 - output_accuracy: 0.5213 - auxilliary_output_1_accuracy: 0.4969 - auxilliary_output_2_accuracy: 0.5137 - val_loss: 2.0529 - val_output_loss: 1.3035 - val_auxilliary_output_1_loss: 1.2705 - val_auxilliary_output_2_loss: 1.2276 - val_output_accuracy: 0.5229 - val_auxilliary_output_1_accuracy: 0.5401 - val_auxilliary_output_2_accuracy: 0.5531
# Epoch 7/25
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.01.
# 196/196 [==============================] - 353s 2s/step - loss: 1.9279 - output_loss: 1.1736 - auxilliary_output_1_loss: 1.2886 - auxilliary_output_2_loss: 1.2259 - output_accuracy: 0.5733 - auxilliary_output_1_accuracy: 0.5342 - auxilliary_output_2_accuracy: 0.5577 - val_loss: 1.8793 - val_output_loss: 1.1635 - val_auxilliary_output_1_loss: 1.1885 - val_auxilliary_output_2_loss: 1.1974 - val_output_accuracy: 0.5876 - val_auxilliary_output_1_accuracy: 0.5746 - val_auxilliary_output_2_accuracy: 0.5832
# Epoch 8/25
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0096.
# 196/196 [==============================] - 353s 2s/step - loss: 1.7545 - output_loss: 1.0547 - auxilliary_output_1_loss: 1.2031 - auxilliary_output_2_loss: 1.1297 - output_accuracy: 0.6198 - auxilliary_output_1_accuracy: 0.5693 - auxilliary_output_2_accuracy: 0.5938 - val_loss: 1.7499 - val_output_loss: 1.0765 - val_auxilliary_output_1_loss: 1.1879 - val_auxilliary_output_2_loss: 1.0568 - val_output_accuracy: 0.6086 - val_auxilliary_output_1_accuracy: 0.5735 - val_auxilliary_output_2_accuracy: 0.6195
# Epoch 9/25
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0096.
# 196/196 [==============================] - 352s 2s/step - loss: 1.6203 - output_loss: 0.9638 - auxilliary_output_1_loss: 1.1401 - auxilliary_output_2_loss: 1.0483 - output_accuracy: 0.6535 - auxilliary_output_1_accuracy: 0.5923 - auxilliary_output_2_accuracy: 0.6251 - val_loss: 1.4966 - val_output_loss: 0.9110 - val_auxilliary_output_1_loss: 1.0157 - val_auxilliary_output_2_loss: 0.9362 - val_output_accuracy: 0.6739 - val_auxilliary_output_1_accuracy: 0.6402 - val_auxilliary_output_2_accuracy: 0.6692
# Epoch 10/25
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0096.
# 196/196 [==============================] - 352s 2s/step - loss: 1.5001 - output_loss: 0.8854 - auxilliary_output_1_loss: 1.0722 - auxilliary_output_2_loss: 0.9771 - output_accuracy: 0.6850 - auxilliary_output_1_accuracy: 0.6180 - auxilliary_output_2_accuracy: 0.6553 - val_loss: 1.4927 - val_output_loss: 0.9314 - val_auxilliary_output_1_loss: 0.9718 - val_auxilliary_output_2_loss: 0.8991 - val_output_accuracy: 0.6736 - val_auxilliary_output_1_accuracy: 0.6582 - val_auxilliary_output_2_accuracy: 0.6816
# Epoch 11/25
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0096.
# 196/196 [==============================] - 352s 2s/step - loss: 1.4089 - output_loss: 0.8260 - auxilliary_output_1_loss: 1.0240 - auxilliary_output_2_loss: 0.9189 - output_accuracy: 0.7059 - auxilliary_output_1_accuracy: 0.6361 - auxilliary_output_2_accuracy: 0.6753 - val_loss: 1.3719 - val_output_loss: 0.8356 - val_auxilliary_output_1_loss: 0.9302 - val_auxilliary_output_2_loss: 0.8574 - val_output_accuracy: 0.6974 - val_auxilliary_output_1_accuracy: 0.6716 - val_auxilliary_output_2_accuracy: 0.6911
# Epoch 12/25
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0096.
# 196/196 [==============================] - 353s 2s/step - loss: 1.3022 - output_loss: 0.7541 - auxilliary_output_1_loss: 0.9722 - auxilliary_output_2_loss: 0.8549 - output_accuracy: 0.7329 - auxilliary_output_1_accuracy: 0.6556 - auxilliary_output_2_accuracy: 0.6981 - val_loss: 1.2651 - val_output_loss: 0.7522 - val_auxilliary_output_1_loss: 0.8977 - val_auxilliary_output_2_loss: 0.8118 - val_output_accuracy: 0.7346 - val_auxilliary_output_1_accuracy: 0.6803 - val_auxilliary_output_2_accuracy: 0.7133
# Epoch 13/25
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0096.
# 196/196 [==============================] - 353s 2s/step - loss: 1.2096 - output_loss: 0.6929 - auxilliary_output_1_loss: 0.9235 - auxilliary_output_2_loss: 0.7989 - output_accuracy: 0.7544 - auxilliary_output_1_accuracy: 0.6737 - auxilliary_output_2_accuracy: 0.7179 - val_loss: 1.2077 - val_output_loss: 0.7231 - val_auxilliary_output_1_loss: 0.8562 - val_auxilliary_output_2_loss: 0.7590 - val_output_accuracy: 0.7414 - val_auxilliary_output_1_accuracy: 0.6951 - val_auxilliary_output_2_accuracy: 0.7328
# Epoch 14/25
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0096.
# 196/196 [==============================] - 353s 2s/step - loss: 1.1384 - output_loss: 0.6437 - auxilliary_output_1_loss: 0.8894 - auxilliary_output_2_loss: 0.7595 - output_accuracy: 0.7742 - auxilliary_output_1_accuracy: 0.6852 - auxilliary_output_2_accuracy: 0.7310 - val_loss: 1.1859 - val_output_loss: 0.7163 - val_auxilliary_output_1_loss: 0.8441 - val_auxilliary_output_2_loss: 0.7212 - val_output_accuracy: 0.7498 - val_auxilliary_output_1_accuracy: 0.7005 - val_auxilliary_output_2_accuracy: 0.7461
# Epoch 15/25
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0096.
# 196/196 [==============================] - 352s 2s/step - loss: 1.0524 - output_loss: 0.5858 - auxilliary_output_1_loss: 0.8482 - auxilliary_output_2_loss: 0.7073 - output_accuracy: 0.7936 - auxilliary_output_1_accuracy: 0.6989 - auxilliary_output_2_accuracy: 0.7494 - val_loss: 1.1489 - val_output_loss: 0.6721 - val_auxilliary_output_1_loss: 0.8202 - val_auxilliary_output_2_loss: 0.7692 - val_output_accuracy: 0.7681 - val_auxilliary_output_1_accuracy: 0.7102 - val_auxilliary_output_2_accuracy: 0.7314
# Epoch 16/25
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.009216.
# 196/196 [==============================] - 353s 2s/step - loss: 0.9803 - output_loss: 0.5395 - auxilliary_output_1_loss: 0.8085 - auxilliary_output_2_loss: 0.6608 - output_accuracy: 0.8108 - auxilliary_output_1_accuracy: 0.7157 - auxilliary_output_2_accuracy: 0.7670 - val_loss: 1.1696 - val_output_loss: 0.7459 - val_auxilliary_output_1_loss: 0.7424 - val_auxilliary_output_2_loss: 0.6699 - val_output_accuracy: 0.7542 - val_auxilliary_output_1_accuracy: 0.7388 - val_auxilliary_output_2_accuracy: 0.7673
# Epoch 17/25
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.009216.
# 196/196 [==============================] - 353s 2s/step - loss: 0.9204 - output_loss: 0.4967 - auxilliary_output_1_loss: 0.7839 - auxilliary_output_2_loss: 0.6285 - output_accuracy: 0.8249 - auxilliary_output_1_accuracy: 0.7253 - auxilliary_output_2_accuracy: 0.7799 - val_loss: 1.0389 - val_output_loss: 0.6153 - val_auxilliary_output_1_loss: 0.7354 - val_auxilliary_output_2_loss: 0.6768 - val_output_accuracy: 0.7870 - val_auxilliary_output_1_accuracy: 0.7430 - val_auxilliary_output_2_accuracy: 0.7617
# Epoch 18/25
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.009216.
# 196/196 [==============================] - 355s 2s/step - loss: 0.8570 - output_loss: 0.4530 - auxilliary_output_1_loss: 0.7570 - auxilliary_output_2_loss: 0.5897 - output_accuracy: 0.8406 - auxilliary_output_1_accuracy: 0.7318 - auxilliary_output_2_accuracy: 0.7919 - val_loss: 1.0171 - val_output_loss: 0.5995 - val_auxilliary_output_1_loss: 0.7433 - val_auxilliary_output_2_loss: 0.6486 - val_output_accuracy: 0.7964 - val_auxilliary_output_1_accuracy: 0.7387 - val_auxilliary_output_2_accuracy: 0.7698
# Epoch 19/25
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.009216.
# 196/196 [==============================] - 354s 2s/step - loss: 0.8108 - output_loss: 0.4206 - auxilliary_output_1_loss: 0.7356 - auxilliary_output_2_loss: 0.5652 - output_accuracy: 0.8531 - auxilliary_output_1_accuracy: 0.7396 - auxilliary_output_2_accuracy: 0.8026 - val_loss: 1.0118 - val_output_loss: 0.6106 - val_auxilliary_output_1_loss: 0.7069 - val_auxilliary_output_2_loss: 0.6305 - val_output_accuracy: 0.7953 - val_auxilliary_output_1_accuracy: 0.7545 - val_auxilliary_output_2_accuracy: 0.7813
# Epoch 20/25
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.009216.
# 196/196 [==============================] - 355s 2s/step - loss: 0.7347 - output_loss: 0.3693 - auxilliary_output_1_loss: 0.6984 - auxilliary_output_2_loss: 0.5197 - output_accuracy: 0.8704 - auxilliary_output_1_accuracy: 0.7553 - auxilliary_output_2_accuracy: 0.8189 - val_loss: 1.0408 - val_output_loss: 0.6312 - val_auxilliary_output_1_loss: 0.6912 - val_auxilliary_output_2_loss: 0.6740 - val_output_accuracy: 0.7891 - val_auxilliary_output_1_accuracy: 0.7577 - val_auxilliary_output_2_accuracy: 0.7689
# Epoch 21/25
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.009216.
# 196/196 [==============================] - 354s 2s/step - loss: 0.7258 - output_loss: 0.3659 - auxilliary_output_1_loss: 0.6918 - auxilliary_output_2_loss: 0.5079 - output_accuracy: 0.8722 - auxilliary_output_1_accuracy: 0.7569 - auxilliary_output_2_accuracy: 0.8230 - val_loss: 0.9736 - val_output_loss: 0.5980 - val_auxilliary_output_1_loss: 0.6698 - val_auxilliary_output_2_loss: 0.5822 - val_output_accuracy: 0.8082 - val_auxilliary_output_1_accuracy: 0.7655 - val_auxilliary_output_2_accuracy: 0.8023
# Epoch 22/25
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.009216.
# 196/196 [==============================] - 354s 2s/step - loss: 0.6702 - output_loss: 0.3269 - auxilliary_output_1_loss: 0.6636 - auxilliary_output_2_loss: 0.4806 - output_accuracy: 0.8847 - auxilliary_output_1_accuracy: 0.7653 - auxilliary_output_2_accuracy: 0.8315 - val_loss: 1.0354 - val_output_loss: 0.6458 - val_auxilliary_output_1_loss: 0.6924 - val_auxilliary_output_2_loss: 0.6062 - val_output_accuracy: 0.7969 - val_auxilliary_output_1_accuracy: 0.7581 - val_auxilliary_output_2_accuracy: 0.7959
# Epoch 23/25
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.009216.
# 196/196 [==============================] - 353s 2s/step - loss: 0.6077 - output_loss: 0.2842 - auxilliary_output_1_loss: 0.6359 - auxilliary_output_2_loss: 0.4422 - output_accuracy: 0.8996 - auxilliary_output_1_accuracy: 0.7757 - auxilliary_output_2_accuracy: 0.8445 - val_loss: 1.0024 - val_output_loss: 0.6116 - val_auxilliary_output_1_loss: 0.6940 - val_auxilliary_output_2_loss: 0.6085 - val_output_accuracy: 0.8062 - val_auxilliary_output_1_accuracy: 0.7599 - val_auxilliary_output_2_accuracy: 0.7935
# Epoch 24/25
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 196/196 [==============================] - 353s 2s/step - loss: 0.5796 - output_loss: 0.2652 - auxilliary_output_1_loss: 0.6243 - auxilliary_output_2_loss: 0.4236 - output_accuracy: 0.9069 - auxilliary_output_1_accuracy: 0.7807 - auxilliary_output_2_accuracy: 0.8505 - val_loss: 0.9708 - val_output_loss: 0.5903 - val_auxilliary_output_1_loss: 0.6788 - val_auxilliary_output_2_loss: 0.5895 - val_output_accuracy: 0.8183 - val_auxilliary_output_1_accuracy: 0.7640 - val_auxilliary_output_2_accuracy: 0.8002
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.008847359999999999.
# 196/196 [==============================] - 353s 2s/step - loss: 0.5311 - output_loss: 0.2305 - auxilliary_output_1_loss: 0.6042 - auxilliary_output_2_loss: 0.3977 - output_accuracy: 0.9178 - auxilliary_output_1_accuracy: 0.7878 - auxilliary_output_2_accuracy: 0.8583 - val_loss: 1.0071 - val_output_loss: 0.6224 - val_auxilliary_output_1_loss: 0.6567 - val_auxilliary_output_2_loss: 0.6256 - val_output_accuracy: 0.8118 - val_auxilliary_output_1_accuracy: 0.7715 - val_auxilliary_output_2_accuracy: 0.7921

# %%
print(history.history['output_accuracy'][-1])
# Out:
# 0.9178400039672852

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'output_loss', 'auxilliary_output_1_loss', 'auxilliary_output_2_loss', 'output_accuracy', 'auxilliary_output_1_accuracy', 'auxilliary_output_2_accuracy', 'val_loss', 'val_output_loss', 'val_auxilliary_output_1_loss', 'val_auxilliary_output_2_loss', 'val_output_accuracy', 'val_auxilliary_output_1_accuracy', 'val_auxilliary_output_2_accuracy', 'lr'])

# %%
# Final Validation Accuracy
history.history['val_output_accuracy'][-1]
# Out:
# 0.8118000030517578
